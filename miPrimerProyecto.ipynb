# %% [markdown]
# <a href="https://colab.research.google.com/github/ze09laya/PROGRAIII-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saludo = "Hola chicos de progra III"
print(saludo, "Primera letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)

boleano = True
print(boleano)
# Out:
# Hola chicos de progra III Primera letra del saludo Hola
# 5.25
# True

# %%
print("Sumar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type(respuesta))

print("Respuesta:", respuesta)

respueta = "Suma Ccompleta"
print(respuesta, type(respuesta))
# Out:
# Sumar dos numeros:
# Num 1: 5.5
# Num 2: 6
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta: 11.5
# 11.5 <class 'float'>

# %%
print("Reste dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) - float(num2)

print(type(num1), type(num2), type(respuesta))

print("Respuesta:", respuesta)

respueta = "Suma Ccompleta"
print(respuesta, type(respuesta))
# Out:
# Reste dos numeros:
# Num 1: 4
# Num 2: 1
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta: 3.0
# 3.0 <class 'float'>

# %%
print("Dividir dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) / float(num2)

print(type(num1), type(num2), type(respuesta))

print("Respuesta:", respuesta)

respueta = "Suma Ccompleta"
print(respuesta, type(respuesta))
# Out:
# Dividir dos numeros:
# Num 1: 4
# Num 2: 2
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta: 2.0
# 2.0 <class 'float'>

# %%
print("Multiplicar dos numeros: ")
num1 = input("Num 1: ")
num2 = input("Num 2: ")
respuesta = float(num1) * float(num2)

print(type(num1), type(num2), type(respuesta))

print("Respuesta:", respuesta)

respueta = "Suma Ccompleta"
print(respuesta, type(respuesta))
# Out:
# Multiplicar dos numeros:
# Num 1: 3
# Num 2: 3
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta: 9.0
# 9.0 <class 'float'>

# %%
saludo = "Hola chicos de progra"
print("Primer elemento de la cadena", saludo[0])
print("Rango de cadena", saludo[0:4])
print("Ultimo elemento", saludo[-1])
print("Ultimo elemento", saludo[len(saludo)-1])
print("Valores en medio, sin especificar el ultimo valor", saludo[5:])
print("Sin valor al inicio", saludo[:4])
print("Contar del final", saludo[5:-1])
# Out:
# Primer elemento de la cadena H
# Rango de cadena Hola
# Ultimo elemento a
# Ultimo elemento a
# Valores en medio, sin especificar el ultimo valor chicos de progra
# Sin valor al inicio Hola
# Contar del final chicos de progr

# %%
def suma(num1, num2):
  respuesta = float(num1) + float(num2)
  return respuesta

# %%
def resta (num1, num2):
  respuesta = float(num1) - float(num2)
  return respuesta

# %%
num1 = input("Num 1: ")
num2 = input("Num 2: ")
print("La suma: ", suma(num1, num2))
print("La Resta: ", resta(num1, num2))
# Out:
# Num 1: 8
# Num 2: 4
# La suma:  12.0
# La Resta:  4.0

# %%
def convrCaf(celcius):
  return float(celcius)*9/5 + 32

# %%
c = input("Grados Celcius: ")
print("Grados Ferenheit:", convrCaf(c))
# Out:
# Grados Celcius: 32
# Grados Ferenheit: 89.6

# %%
def converFac(f):
  return (float(f)-32) *5/9

# %%
f = input("Farenheit: ")
print("Grados Celcius:", converFac(f))
# Out:
# Farenheit: 23
# Grados Celcius: -5.0

# %%
def converCak(c):
  return float(c) + 273.15

# %%
c = input("Celcius: ")
print("Grados Kelvin:", converCak(c))
# Out:
# Celcius: 12
# Grados Kelvin: 285.15

# %%
convertir = lambda c: float(c)*9/5 + 32

# %%
c = float(input("Grados Celcius: "))
print("Grados Ferenheit:", convertir(c))
# Out:
# Grados Celcius: 34
# Grados Ferenheit: 93.2

# %% [markdown]
# Hacer los siguiente ejercicio en python haciendo uso de funciones anonimas:
#
# Farenheit a celcius
# Celcius a kelvin
# Calcular el sueldo de un empleado. hrs * valor de horas * 30 dias las deducciones: ISSS, AFP, ISR (Ver tabla del MH)
# Elevar un numero a su exponente
